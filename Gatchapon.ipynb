# %%
import pandas as pd
import time
import sys
import textdot
import os

# %%
items = pd.read_csv('data/items.csv')
items = items.drop(columns=['Description', 'Index'])
descriptions = pd.read_csv('data/descriptions.csv')
descriptions = descriptions.drop(columns='Repeatable?')

items.head(5)
# Out:
#     Class                        Item
# 0  Ranger        Whisper of the Noose
# 1  Ranger              Very Cross Bow
# 2  Ranger           Greased Lightning
# 3  Ranger  The Rose Tinted Spectacles
# 4  Ranger         Ring of the Phoenix

# %%
descriptions.head(5)
# Out:
#          Type                  Name Pill Shape    Size  \
# 0      Weapon  Whisper of the Noose     Oblong   Large
# 1     Trinket         Forked Tongue     Sphere   Small
# 2      Weapon        Very-Cross Bow     Oblong  Medium
# 3   Accessory  Buffoon's Pantaloons     Sphere  Medium
# 4  Consumable     Greased Lightning     Sphere   Small
#
#                                                Class  \
# 0                                    Ranger, Warlock
# 1  Paladin, Rogue, Bard, Cleric, Wizard, Barbaria...
# 2                        Ranger, Barbarian, Fighter,
# 3                     Bard, Barbarian, Monk, Fighter
# 4  Ranger, Rogue, Paladin, Barbarian, Fighter, Wa...
#
#                                          Description
# 0  An elegant looking bow made of mahogany with a...
# 1  A bloody severed tongue split down the middle....
# 2  An ill-conceived and short-lived partnership b...
# 3  A gaudy pair of pantaloons that only the most ...
# 4  A tin of shimmering grease that reminds you of...

# %%
# wow how pretty
print('                                                                                    ')
print('                              Welcome to Fantasy Gatchapon Systems!                        ')
print("                                   I'm Figis, smash my hand!")
print('                                                                                    ')
print('                   Oh please, oh please! I do love it so when people do that')
print('                                                                                    ')
print('                                           @@@@@@@                                  ')
print('                                       @@@@@     @@@@@                              ')
print('                                     @@@@           @@@@                            ')
print('                                    @@                 @@                           ')
print('                                   @@                   @@                          ')
print('                                   @@                   @@                          ')
print('                                    @@                 @@                           ')
print('                                     @@               @@                            ')
print('                                       @@            @@                             ')
print('                                         @@@      @@@                               ')
print('                                            @@@@@@              ___                 ')
print('                                            @    @             /   \                ')
print('                                 @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /                ')
print('                                 @@   ____          ____   @@   | |                 ')
print('                                 @@  |   x|        |x   |  @@   | |                 ')
print('                                 @@                        @@   | |                 ')
print('                                 @@      /@@@@@@@@@@\      @@   | |                 ')
print('                                 @@      @   ____   @      @@___| |_                ')
print('                                 @@      @          @      @@_______|               ')
print('                                 @@      @  |____|  @      @@_______|               ')
print('                                 @@      @          @      @@                       ')
print('                                 @@      \@@@@@@@@@@/      @@                       ')
print('                                 @@                        @@                       ')
print('                                 @@@@@@@@@    | |   @@@@@@@@@                       ')
print('                                  @@@@@@@@@@@@@@@@@@@@@@@@@@                        ')
print('                                                                                    ')
print('                                         Insert a coin?                             ')
print('                                         [Y]es / [N]o')

choice = raw_input()

if choice == 'Y':
    print('------------------------------------------------------------------------------------------------------')
    print('Figis: Oh wait, what class are you again? (Example: I am Figis and my class is a: "Robot")')
    print('------------------------------------------------------------------------------------------------------')
    random_class = raw_input()
    print('------------------------------------------------------------------------------------------------------')
# Out:
#
#                               Welcome to Fantasy Gatchapon Systems!
#                                    I'm Figis, smash my hand!
#
#                    Oh please, oh please! I do love it so when people do that
#
#                                            @@@@@@@
#                                        @@@@@     @@@@@
#                                      @@@@           @@@@
#                                     @@                 @@
#                                    @@                   @@
#                                    @@                   @@
#                                     @@                 @@
#                                      @@               @@
#                                        @@            @@
#                                          @@@      @@@
#                                             @@@@@@              ___
#                                             @    @             /   \
#                                  @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /
#                                  @@   ____          ____   @@   | |
#                                  @@  |   x|        |x   |  @@   | |
#                                  @@                        @@   | |
#                                  @@      /@@@@@@@@@@\      @@   | |
#                                  @@      @   ____   @      @@___| |_
#                                  @@      @          @      @@_______|
#                                  @@      @  |____|  @      @@_______|
#                                  @@      @          @      @@
#                                  @@      \@@@@@@@@@@/      @@
#                                  @@                        @@
#                                  @@@@@@@@@    | |   @@@@@@@@@
#                                   @@@@@@@@@@@@@@@@@@@@@@@@@@
#
#                                          Insert a coin?
#                                          [Y]es / [N]o
# Y
# ------------------------------------------------------------------------------------------------------
# Figis: Oh wait, what class are you again? (Example: I am Figis and my class is a: "Robot")
# ------------------------------------------------------------------------------------------------------
# Ranger
# ------------------------------------------------------------------------------------------------------

# %%
# Out:
# 'Ranger'

# %%
# Out:
# 'Ranger'

# %%
if random_class: 
    random_item_df = items[items['Class'].str.contains(random_class) == True]
    random_item = random_item_df.sample(n=1)
    random_item_name = random_item['Item'].item()
else:
    random_class = items['Class'].sample(n=1).item()
    random_item_name = items['Class'] == random_class
    random_item_df = items[random_item_name]
    random_item = random_item_df.sample(n=1)
    random_item_name = random_item['Item'].item()

# %%
random_class = items['Class'].sample(n=1).item()
random_item_name = items['Class'] == random_class
random_item_df = items[random_item_name]
random_item = random_item_df.sample(n=1)
random_item_name = random_item['Item'].item()

# %%
random_item_df
# Out:
#        Class  Index                          Item
# 188  Fighter      1              Awareness Frames
# 189  Fighter      2           Ring of Sweet Flips
# 190  Fighter      3           Ring of the Phoenix
# 191  Fighter      4            Crest of Foresight
# 192  Fighter      5              Demon Eye Amulet
# 193  Fighter      6                       Needler
# 194  Fighter      7     Jackrabbit's Speedy Socks
# 195  Fighter      8                Very Cross Bow
# 196  Fighter      9        Feather Weight Curiass
# 197  Fighter     10         Proficiency Vestments
# 198  Fighter     11             Sword of the Wind
# 199  Fighter     12  Pickpocket's Peerless Grasps
# 200  Fighter     13               Defender's Dial
# 201  Fighter     14      Ring of the Giant Slayer
# 202  Fighter     15          Buffoon's Pantaloons
# 203  Fighter     16               Broom of Flying
# 204  Fighter     17                     Lucky Egg
# 205  Fighter     18             Greased Lightning
# 206  Fighter     19                  Railsplitter
# 207  Fighter     20               Fletcher's Mitt
# 208  Fighter     19                  Railsplitter
# 209  Fighter     20               Fletcher's Mitt

# %%
random_item_name
# Out:
# 'Forked Tongue'

# %%
random_class = items['Class'].sample(n=1).item()
random_item_name = items['Class'] == random_class
print(random_item_name)
random_item_df = items[random_item_name]
random_item = random_item_df.sample(n=1)
random_item_name = random_item['Item'].item()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Name: Class, Length: 251, dtype: bool

# %%
find_item = descriptions['Name'] == random_item_name
item = descriptions[find_item].drop(columns='Class')
item_name = item['Name'].item()
item_type = item['Type'].item()
pill_shape = item['Pill Shape'].item()
item_size = item['Size'].item()
item_description = item['Description'].item()
item_description
# Out:
# "This plastic ring features a rad sticker of a skateboarder, and feels kinda like it'll bend if you mess with it too much. You gain +2 to dexterity and athletic checks, and addvantage on dexterity saving throws."

# %%
print('                                                                                           ')                                                  
print('                                          Welcome to DnD Gatchapon!                        ') 
print('                                                                                           ') 
print('                                                                                           ') 
print('                                                  @@@@@@@                                  ')                                         
print('                                              @@@@@     @@@@@                              ')                                        
print('                                            @@@@           @@@@                            ')                                         
print('                                           @@                 @@                           ')                                           
print('                                          @@                   @@                          ')                                            
print('                                          @@                   @@                          ')                                           
print('                                           @@                 @@                           ')                                          
print('                                            @@               @@                            ')                                            
print('                                              @@            @@                             ')                                            
print('                                                @@@      @@@                               ')                                            
print('                                                   @@@@@@              ___                 ')                                            
print('                                                   @    @             /   \                ')                                            
print('                                        @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /                ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@      /@@@@@@@@@@\      @@   | |                 ')                                            
print('                                        @@      @   ____   @      @@___| |_                ')                                            
print('                                        @@      @          @      @@       |               ')                                            
print('                                        @@      @  |____|  @      @@_______|               ')                                            
print('                                        @@      @          @      @@                       ')                                            
print('                                        @@      \@@@@@@@@@@/      @@                       ')                                            
print('                                        @@                        @@                       ')                                            
print('                                        @@@@@@@@@          @@@@@@@@@                       ')                                            
print('                                          @@@@@@@@@@@@@@@@@@@@@@@@@@                       ')
print('                                                                                           ') 
print('                                                                                           ') 
print('                                                 Press Enter                               ') 
input('                                                  to begin                                 ')
# Out:
#
#                                           Welcome to DnD Gatchapon!
#
#
#                                                   @@@@@@@
#                                               @@@@@     @@@@@
#                                             @@@@           @@@@
#                                            @@                 @@
#                                           @@                   @@
#                                           @@                   @@
#                                            @@                 @@
#                                             @@               @@
#                                               @@            @@
#                                                 @@@      @@@
#                                                    @@@@@@              ___
#                                                    @    @             /   \
#                                         @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /
#                                         @@                        @@   | |
#                                         @@                        @@   | |
#                                         @@                        @@   | |
#                                         @@      /@@@@@@@@@@\      @@   | |
#                                         @@      @   ____   @      @@___| |_
#                                         @@      @          @      @@       |
#                                         @@      @  |____|  @      @@_______|
#                                         @@      @          @      @@
#                                         @@      \@@@@@@@@@@/      @@
#                                         @@                        @@
#                                         @@@@@@@@@          @@@@@@@@@
#                                           @@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
#                                                  Press Enter
#                                                   to begin

# %%
print('                                                                                           ')                                                  
print('                                            Lets see what we get.                          ') 
print('                                                                                           ') 
print('                                                                                           ') 
print('                                                  @@@@@@@                                  ')                                         
print('                                              @@@@@     @@@@@                              ')                                        
print('                                            @@@@           @@@@                            ')                                         
print('                                           @@                 @@                           ')                                           
print('                                          @@                   @@                          ')                                            
print('                                          @@                   @@                          ')                                           
print('                                           @@                 @@                           ')                                          
print('                                            @@               @@                            ')                                            
print('                                              @@            @@                             ')                                            
print('                                                @@@      @@@                               ')                                            
print('                                                   @@@@@@              ___                 ')                                            
print('                                                   @    @             /   \                ')                                            
print('                                        @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /                ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@                        @@   | |                 ')                                            
print('                                        @@      /@@@@@@@@@@\      @@   | |                 ')                                            
print('                                        @@      @          @      @@___| |_                ')                                            
print('                                        @@      @          @      @@       |               ')                                            
print('                                        @@      @          @      @@_______|               ')                                            
print('                                        @@      @          @      @@                       ')                                            
print('                                        @@      \@@@@@@@@@@/      @@                       ')                                            
print('                                        @@                        @@                       ')                                            
print('                                        @@@@@@@@@          @@@@@@@@@                       ')                                            
print('                                          @@@@@@@@@@@@@@@@@@@@@@@@@@                       ')
print('                                                                                           ') 
print('                                                                                           ') 
print('                                                 Press Enter                               ') 
print('                                                                                           ')
# Out:
#
#                                             Lets see what we get.
#
#
#                                                   @@@@@@@
#                                               @@@@@     @@@@@
#                                             @@@@           @@@@
#                                            @@                 @@
#                                           @@                   @@
#                                           @@                   @@
#                                            @@                 @@
#                                             @@               @@
#                                               @@            @@
#                                                 @@@      @@@
#                                                    @@@@@@              ___
#                                                    @    @             /   \
#                                         @@@@@@@@@@@@@@@@@@@@@@@@@@@@  \   /
#                                         @@                        @@   | |
#                                         @@                        @@   | |
#                                         @@                        @@   | |
#                                         @@      /@@@@@@@@@@\      @@   | |
#                                         @@      @          @      @@___| |_
#                                         @@      @          @      @@       |
#                                         @@      @          @      @@_______|
#                                         @@      @          @      @@
#                                         @@      \@@@@@@@@@@/      @@
#                                         @@                        @@
#                                         @@@@@@@@@          @@@@@@@@@
#                                           @@@@@@@@@@@@@@@@@@@@@@@@@@
#
#
#                                                  Press Enter
#                                                   to begin
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing
